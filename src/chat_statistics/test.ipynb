# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from collections import Counter
from wordcloud import WordCloud

# %%
import arabic_reshaper
from bidi.algorithm import get_display

# %%
with open('../data/online.json') as f:
    data = json.load(f)

# %%
msg_iter = iter(data['messages'])

# %%
stop_words = open('stopwords.txt').readlines()
stop_words = list(map(str.strip, stop_words))

# %%
text_content = ''

for msg in data['messages']:
    if type(msg['text']) is str:
        text_content += f" {msg['text']}"

# %%
#normalizer = Normalizer()
#text_content = normalizer.normalize(text_content)

# %%
text_content = arabic_reshaper.reshape(text_content)
text_content = get_display(text_content)

# %%
wordcloud = WordCloud(font_path='./BHoma.ttf', background_color='white',width=900,height=900).generate(text_content)

# %%
import matplotlib.pyplot as plt

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 899.5, 899.5, -0.5)

# %%
Counter(text_content.split()).most_common()[1490:]
# Out:
# [('ﺁﯾﻨﺪﻩ', 9),
#  ('ﻧﻤﯿﺸﻪ؟', 9),
#  ('ﮐﺠﺎﺳﺖ', 9),
#  ('ﺷﺮﻣﻨﺪﻩ', 9),
#  ('ﺭﺑﻊ', 9),
#  ('apt', 9),
#  ('ﺣﺎﺻﻞ', 9),
#  ('ﮐﻼ', 9),
#  ('ﻣﯿﺪﯾﻢ', 9),
#  ('ﻭﻗﺘﺎ', 9),
#  ('ﺯﺩ', 9),
#  ('ﭘﯿﺸﺎﭘﯿﺶ', 9),
#  ('ﻫﻤﻪﯼ', 9),
#  ('ﺿﻤﻦ', 9),
#  ('ﻣﺸﮑﻠﻢ', 9),
#  ('ﺭﯾﺎﺿﯽ', 9),
#  ('ﺩﺍﺭﯾﻢ؟', 9),
#  ('ﻧﺸﺪﻩ؟', 9),
#  ('ﻣﻔﺎﻫﯿﻢ', 9),
#  ('5', 9),
#  ('ﺷﺪ،', 9),
#  ('ﺩﺍﻧﻠﻮﺩﺵ', 9),
#  ('ﻣﻠﺖ', 9),
#  ('programming', 9),
#  ('ﺁﺷﻨﺎ', 9),
#  ('oop', 9),
#  ('6', 9),
#  ('ﮔﻞ', 9),
#  ('ﺧﺎﻣﻮﺵ', 9),
#  ('ﻫﺎ.', 9),
#  ('ﮐﺎﺭﻡ', 9),
#  ('ﻧﻤﯽﺷﻪ', 9),
#  ('ﺍﯾﻤﭙﻮﺭﺕ', 9),
#  ('ﻫﺴﺘﯿﺪ', 9),
#  ('ﺑﻔﺮﺳﺘﯿﺪ', 9),
#  ('ﻣﯿﺨﻮﺍﻥ', 9),
#  ('ﺁﺯﺍﺩ', 9),
#  ('ﺣﻘﯿﻘﺘﺎ', 9),
#  ('ﺣﻔﻆ', 9),
#  ('ﺗﮑﺮﺍﺭﯼ', 9),
#  ('variable', 9),
#  ('ﻣﯿﻠﯿﻮﻥ', 9),
#  ('ﻗﺪﺭ', 9),
#  ('ﺑﺎﺯﯼ', 9),
#  ('ﺳﺨﺘﻪ', 9),
#  ('ﻓﺎﻧﺪ', 9),
#  ('ﻣﺼﺎﺣﺒﻪ', 9),
#  (':)))))', 9),
#  ('ﺍﻓﺮﺍﺩﯼ', 9),
#  (':((', 9),
#  (':))))))', 9),
#  ('ﺧﺪﻣﺘﺘﻮﻥ', 9),
#  ('ﻣﯽﺧﻮﺍﺩ', 9),
#  ('export', 9),
#  ('ﺑﺪﻡ.', 9),
#  ('ﻣﯿﺎﻡ', 9),
#  ('ﻧﻤﯿﺘﻮﻧﻪ', 9),
#  ('upgrade', 9),
#  ('ﺍﺩ', 9),
# ...
